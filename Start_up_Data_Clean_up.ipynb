# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings as wn
import matplotlib as plt


pd.set_option('mode.chained_assignment',None)
pd.set_option('display.max_colwidth', -1)
pd.options.display.max_columns = 50
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
dir_path = "C:/Users/vik2nu/Desktop/AI_ML/Term1_2_Project/01_Startup_Data/"
sfin=pd.read_csv(dir_path+'startup_funding.csv')
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
# Sr No                3044 non-null int64
# Date dd/mm/yyyy      3044 non-null object
# Startup Name         3044 non-null object
# Industry Vertical    2873 non-null object
# SubVertical          2108 non-null object
# City  Location       2864 non-null object
# Investors Name       3020 non-null object
# InvestmentnType      3040 non-null object
# Amount in USD        2084 non-null object
# Remarks              419 non-null object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
sfin.tail(10)
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3034  3035   24/01/2015      Aasaanjobs        NaN               NaN
# 3035  3036   24/01/2015      Impartus          NaN               NaN
# 3036  3037   25/01/2015      Thrill App        NaN               NaN
# 3037  3038   27/01/2015      CarDekho.com      NaN               NaN
# 3038  3039   28/01/2015      Grabhouse.com     NaN               NaN
# 3039  3040   29/01/2015      Printvenue        NaN               NaN
# 3040  3041   29/01/2015      Graphene          NaN               NaN
# 3041  3042   30/01/2015      Mad Street Den    NaN               NaN
# 3042  3043   30/01/2015      Simplotel         NaN               NaN
# 3043  3044   31/01/2015      couponmachine.in  NaN               NaN
#
#      City  Location                           Investors Name InvestmentnType  \
# 3034  NaN            Inventus Capital Partners, IDG Ventures  Seed Funding
# ...

# %%
sfin['Startup Name'].value_counts()
# Out:
# Swiggy                     8
# Ola Cabs                   8
# Paytm                      7
# UrbanClap                  6
# Medinfi                    6
# Meesho                     6
# Nykaa                      6
# NoBroker                   6
# Capital Float              5
# Moglix                     5
# Flipkart                   5
# Grofers                    5
# Toppr                      5
# Uniphore                   5
# Jugnoo                     5
# Ola                        4
# RailYatri                  4
# Zoctr                      4
# Byju\\xe2\\x80\\x99s       4
# Fynd                       4
# Magicpin                   4
# BigBasket                  4
# Niki.ai                    4
# Zomato                     4
# Udaan                      4
# Icertis                    4
# Healthians                 4
# Simplilearn                4
# Rivigo                     4
# HealthifyMe                4
#                           ..
# ORIGA Leasing              1
# ...

# %%
sfin['Industry Vertical'].value_counts()
# Out:
# Consumer Internet                            941
# Technology                                   478
# eCommerce                                    186
# Healthcare                                   70
# Finance                                      62
# ECommerce                                    61
# Logistics                                    32
# E-Commerce                                   29
# Education                                    24
# Food & Beverage                              23
# Ed-Tech                                      14
# E-commerce                                   12
# FinTech                                      9
# Ecommerce                                    8
# IT                                           8
# Fin-Tech                                     6
# Real Estate                                  6
# Food and Beverage                            6
# Others                                       6
# Online Food Delivery                         5
# ...

# %%
sfin['InvestmentnType'].value_counts()
# Out:
# Private Equity                 1356
# Seed Funding                   1355
# Seed/ Angel Funding            60
# Seed / Angel Funding           47
# Seed\\nFunding                 30
# Debt Funding                   25
# Series A                       24
# Seed/Angel Funding             23
# Series B                       20
# Series C                       14
# Series D                       12
# Angel / Seed Funding           8
# Seed Round                     7
# Pre-Series A                   4
# Private Equity Round           4
# Seed                           4
# Seed / Angle Funding           3
# Venture Round                  2
# Corporate Round                2
# pre-Series A                   2
# Series E                       2
# Series F                       2
# Equity                         2
# Funding Round                  1
# Seed funding                   1
# Inhouse Funding                1
# Pre Series A                   1
# Crowd Funding                  1
# ...

# %%
sfin['SubVertical'].value_counts()
# Out:
# Online Lending Platform                                                       11
# Online Pharmacy                                                               10
# Food Delivery Platform                                                        8
# Online lending platform                                                       5
# Online Lending                                                                5
# Education                                                                     5
# Online Education Platform                                                     5
# Online Learning Platform                                                      5
# Online Food Delivery                                                          4
# Non-Banking Financial Company                                                 4
# Agri-tech                                                                     3
# Online Payment Gateway                                                        3
# ...

# %%
sfin.isna().sum()
# Out:
# Sr No                0
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    171
# SubVertical          936
# City  Location       180
# Investors Name       24
# InvestmentnType      4
# Amount in USD        960
# Remarks              2625
# dtype: int64

# %%
#irrelevant colums dropped
sfin.drop(['Sr No'],1,inplace=True)
sfin.drop(['Remarks'],1,inplace=True)

# %%
sfin.isna().sum()
# Out:
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    171
# SubVertical          936
# City  Location       180
# Investors Name       24
# InvestmentnType      4
# Amount in USD        960
# dtype: int64

# %%
#Date formating done and erroneous dates replace w/ NaT
sfin['date']=pd.to_datetime(sfin['Date dd/mm/yyyy'],errors='coerce')

# %%
sfin.head(10)
# Out:
#   Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0  09/01/2020      BYJU’S                        E-Tech
# 1  13/01/2020      Shuttl                        Transportation
# 2  09/01/2020      Mamaearth                     E-commerce
# 3  02/01/2020      https://www.wealthbucket.in/  FinTech
# 4  02/01/2020      Fashor                        Fashion and Apparel
# 5  13/01/2020      Pando                         Logistics
# 6  10/01/2020      Zomato                        Hospitality
# 7  12/12/2019      Ecozen                        Technology
# 8  06/12/2019      CarDekho                      E-Commerce
# 9  03/12/2019      Dhruva Space                  Aerospace
#
#                                 SubVertical City  Location  \
# 0  E-learning                                Bengaluru
# 1  App based shuttle service                 Gurgaon
# 2  Retailer of baby and toddler products     Bengaluru
# 3  Online Investment                         New Delhi
# ...

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
# Date dd/mm/yyyy      3044 non-null object
# Startup Name         3044 non-null object
# Industry Vertical    2873 non-null object
# SubVertical          2108 non-null object
# City  Location       2864 non-null object
# Investors Name       3020 non-null object
# InvestmentnType      3040 non-null object
# Amount in USD        2084 non-null object
# date                 3036 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(8)
# memory usage: 214.1+ KB

# %%
sfin.isna().sum()
# Out:
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    171
# SubVertical          936
# City  Location       180
# Investors Name       24
# InvestmentnType      4
# Amount in USD        960
# date                 8
# dtype: int64

# %%
sfin['City  Location'].value_counts()
# Out:
# Bangalore                 700
# Mumbai                    567
# New Delhi                 421
# Gurgaon                   287
# Bengaluru                 141
# Pune                      105
# Hyderabad                 99
# Chennai                   97
# Noida                     92
# Gurugram                  50
# Ahmedabad                 38
# Delhi                     34
# Jaipur                    30
# Kolkata                   21
# Indore                    13
# Chandigarh                11
# Vadodara                  10
# Goa                       10
# Singapore                 8
# Coimbatore                5
# Pune / US                 4
# \\xc2\\xa0Gurgaon         4
# Kanpur                    4
# Nagpur                    3
# Faridabad                 3
# \\xc2\\xa0New Delhi       3
# Bhopal                    3
# Kochi                     2
# Siliguri                  2
# Bangalore / SFO           2
#                          ..
# Menlo Park                1
# ...

# %%
#filling missing city locations w/ India_Other
sfin['City  Location']=sfin['City  Location'].fillna('India_Other')

# %%
sfin.isna().sum()
# Out:
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    171
# SubVertical          936
# City  Location       0
# Investors Name       24
# InvestmentnType      4
# Amount in USD        960
# date                 8
# dtype: int64

# %%
sfin.tail()
# Out:
#      Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039  29/01/2015      Printvenue        NaN               NaN
# 3040  29/01/2015      Graphene          NaN               NaN
# 3041  30/01/2015      Mad Street Den    NaN               NaN
# 3042  30/01/2015      Simplotel         NaN               NaN
# 3043  31/01/2015      couponmachine.in  NaN               NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039  India_Other    Asia Pacific Internet Group        Private Equity
# 3040  India_Other    KARSEMVEN Fund                     Private Equity
# 3041  India_Other    Exfinity Fund, GrowX Ventures.     Private Equity
# 3042  India_Other    MakeMyTrip                         Private Equity
# 3043  India_Other    UK based Group of Angel Investors  Seed Funding
#
#      Amount in USD       date
# 3039  45,00,000    2015-01-29
# 3040  8,25,000     2015-01-29
# 3041  15,00,000    2015-01-30
# 3042  NaN          2015-01-30
# ...

# %%
#replacing missing Industrial vertical data with 'unclassified'
sfin['Industry Vertical']=sfin['Industry Vertical'].fillna('Unclassified')

# %%
sfin.tail()
# Out:
#      Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039  29/01/2015      Printvenue        Unclassified      NaN
# 3040  29/01/2015      Graphene          Unclassified      NaN
# 3041  30/01/2015      Mad Street Den    Unclassified      NaN
# 3042  30/01/2015      Simplotel         Unclassified      NaN
# 3043  31/01/2015      couponmachine.in  Unclassified      NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039  India_Other    Asia Pacific Internet Group        Private Equity
# 3040  India_Other    KARSEMVEN Fund                     Private Equity
# 3041  India_Other    Exfinity Fund, GrowX Ventures.     Private Equity
# 3042  India_Other    MakeMyTrip                         Private Equity
# 3043  India_Other    UK based Group of Angel Investors  Seed Funding
#
#      Amount in USD       date
# 3039  45,00,000    2015-01-29
# 3040  8,25,000     2015-01-29
# 3041  15,00,000    2015-01-30
# 3042  NaN          2015-01-30
# ...

# %%
#getting rid of ',' in amount and converting object to str to float
sfin['amount'] = sfin['Amount in USD'].str.replace(',','')
sfin['amount'] = pd.to_numeric(sfin['amount'], errors='coerce')

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
# Date dd/mm/yyyy      3044 non-null object
# Startup Name         3044 non-null object
# Industry Vertical    3044 non-null object
# SubVertical          2108 non-null object
# City  Location       3044 non-null object
# Investors Name       3020 non-null object
# InvestmentnType      3040 non-null object
# Amount in USD        2084 non-null object
# date                 3036 non-null datetime64[ns]
# amount               2065 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 237.9+ KB

# %%
sfin.tail()
# Out:
#      Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039  29/01/2015      Printvenue        Unclassified      NaN
# 3040  29/01/2015      Graphene          Unclassified      NaN
# 3041  30/01/2015      Mad Street Den    Unclassified      NaN
# 3042  30/01/2015      Simplotel         Unclassified      NaN
# 3043  31/01/2015      couponmachine.in  Unclassified      NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039  India_Other    Asia Pacific Internet Group        Private Equity
# 3040  India_Other    KARSEMVEN Fund                     Private Equity
# 3041  India_Other    Exfinity Fund, GrowX Ventures.     Private Equity
# 3042  India_Other    MakeMyTrip                         Private Equity
# 3043  India_Other    UK based Group of Angel Investors  Seed Funding
#
#      Amount in USD       date     amount
# 3039  45,00,000    2015-01-29  4500000.0
# 3040  8,25,000     2015-01-29  825000.0
# ...

# %%
#dropping orginal amount column as no more relavent
sfin.drop(['Amount in USD'],1,inplace=True)

# %%
sfin.tail()
# Out:
#      Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039  29/01/2015      Printvenue        Unclassified      NaN
# 3040  29/01/2015      Graphene          Unclassified      NaN
# 3041  30/01/2015      Mad Street Den    Unclassified      NaN
# 3042  30/01/2015      Simplotel         Unclassified      NaN
# 3043  31/01/2015      couponmachine.in  Unclassified      NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039  India_Other    Asia Pacific Internet Group        Private Equity
# 3040  India_Other    KARSEMVEN Fund                     Private Equity
# 3041  India_Other    Exfinity Fund, GrowX Ventures.     Private Equity
# 3042  India_Other    MakeMyTrip                         Private Equity
# 3043  India_Other    UK based Group of Angel Investors  Seed Funding
#
#            date     amount
# 3039 2015-01-29  4500000.0
# 3040 2015-01-29  825000.0
# 3041 2015-01-30  1500000.0
# 3042 2015-01-30 NaN
# ...

# %%
#filling missing subvertical information w/ Industry vertical data
sfin['SubVertical']=sfin['SubVertical'].fillna(sfin['Industry Vertical'])

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
# Date dd/mm/yyyy      3044 non-null object
# Startup Name         3044 non-null object
# Industry Vertical    3044 non-null object
# SubVertical          3044 non-null object
# City  Location       3044 non-null object
# Investors Name       3020 non-null object
# InvestmentnType      3040 non-null object
# date                 3036 non-null datetime64[ns]
# amount               2065 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 214.1+ KB

# %%
sfin['Investors Name'].mode()
# Out:
# 0    Undisclosed Investors
# dtype: object

# %%
#Original Date column dropped
sfin.drop(['Date dd/mm/yyyy'],1,inplace=True)

# %%
sfin.tail()
# Out:
#           Startup Name Industry Vertical   SubVertical City  Location  \
# 3039  Printvenue        Unclassified      Unclassified  India_Other
# 3040  Graphene          Unclassified      Unclassified  India_Other
# 3041  Mad Street Den    Unclassified      Unclassified  India_Other
# 3042  Simplotel         Unclassified      Unclassified  India_Other
# 3043  couponmachine.in  Unclassified      Unclassified  India_Other
#
#                          Investors Name InvestmentnType       date     amount
# 3039  Asia Pacific Internet Group        Private Equity 2015-01-29  4500000.0
# 3040  KARSEMVEN Fund                     Private Equity 2015-01-29  825000.0
# 3041  Exfinity Fund, GrowX Ventures.     Private Equity 2015-01-30  1500000.0
# 3042  MakeMyTrip                         Private Equity 2015-01-30 NaN
# 3043  UK based Group of Angel Investors  Seed Funding   2015-01-31  140000.0

# %%
#replacing 8 missing date info with highest mode data 
sfin['date']=sfin['date'].fillna(sfin['date'].mode()[0])
# replace in missing 24 investor name with highest mode data - i.e., undisclosed investor
sfin['Investors Name']=sfin['Investors Name'].fillna(sfin['Investors Name'].mode()[0])

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 8 columns):
# Startup Name         3044 non-null object
# Industry Vertical    3044 non-null object
# SubVertical          3044 non-null object
# City  Location       3044 non-null object
# Investors Name       3044 non-null object
# InvestmentnType      3040 non-null object
# date                 3044 non-null datetime64[ns]
# amount               2065 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 190.3+ KB

# %%
#Clean-up investment type - sorting into investment categories
sfin['InvestmentnType']=sfin['InvestmentnType'].str.lower()

# %%
sfin['InvestmentnType'].value_counts()
# Out:
# seed funding                   1356
# private equity                 1356
# seed/ angel funding            60
# seed / angel funding           47
# seed\\nfunding                 30
# debt funding                   25
# series a                       24
# seed/angel funding             23
# series b                       20
# series c                       14
# series d                       12
# pre-series a                   8
# angel / seed funding           8
# seed round                     7
# seed                           4
# private equity round           4
# seed / angle funding           3
# series f                       2
# crowd funding                  2
# corporate round                2
# venture round                  2
# equity                         2
# series e                       2
# debt                           1
# term loan                      1
# series b (extension)           1
# private                        1
# debt-funding                   1
# ...

# %%
private_angel=['seed funding','seed/ angel funding','seed / angel funding','seed\\nfunding','seed/angel funding','angel / seed funding','seed round','private equity round','seed,seed / angle funding','seed funding round','private','single venture','angel funding','angel round','private\\nequity','seed / angle funding', 'seed\\\\nfunding', 'private\\\\nequity','privateequity','private funding','angel','seed','private equity']

# %%
venture_capital=['venture round','venture - series unknown','venture','single venture','corporate round']

# %%
pre_series_A_B=['pre-series a','series a','series b','pre series a','series b (extension)']

# %%
series_C_H=['series c','series d','series f','series e','series j','series g','series h']

# %%
debt_fund=['debt funding','term loan','structured debt','debt-funding','debt and preference capital','debt']

# %%
other_funding=['crowd funding','mezzanine','maiden round','funding round','bridge round','inhouse funding','equity based funding','equity']

# %%
sfin['invst_type_sorted']=sfin['InvestmentnType']

# %%
for x in sfin['invst_type_sorted']:
    if x in private_angel:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='private_angel')
    elif x in venture_capital:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='venture_capital')
    elif x in pre_series_A_B:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='pre_series_A_B')
    elif x in series_C_H:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='series_C_H')
    elif x in debt_fund:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='debt_fund')
    elif x in other_funding:
        sfin['invst_type_sorted'] = sfin['invst_type_sorted'].replace(to_replace=x, value='other_funding')

# %%
sfin['invst_type_sorted'].unique()
# Out:
# array(['private_angel', 'series_C_H', 'pre_series_A_B', 'debt_fund',
#        'venture_capital', nan, 'other_funding'], dtype=object)

# %%
#fill missing investment type with other funding
sfin['invst_type_sorted']=sfin['invst_type_sorted'].fillna('other_funding')

# %%
sfin['invst_type_sorted'].value_counts()
# Out:
# private_angel      2907
# pre_series_A_B     54
# series_C_H         33
# debt_fund          30
# other_funding      14
# venture_capital    6
# Name: invst_type_sorted, dtype: int64

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 9 columns):
# Startup Name         3044 non-null object
# Industry Vertical    3044 non-null object
# SubVertical          3044 non-null object
# City  Location       3044 non-null object
# Investors Name       3044 non-null object
# InvestmentnType      3040 non-null object
# date                 3044 non-null datetime64[ns]
# amount               2065 non-null float64
# invst_type_sorted    3044 non-null object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 214.1+ KB

# %%
#Clean-up city data
sfin['City  Location'].unique()
# Out:
# array(['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune',
#        'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar',
#        'Delhi', 'Kormangala', 'Tulangan', 'Hyderabad', 'Burnsville',
#        'Menlo Park', 'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore',
#        'Taramani', 'Andheri', 'Chembur', 'Nairobi', 'Haryana', 'New York',
#        'Karnataka', 'Mumbai/Bengaluru', 'Bhopal',
#        'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US',
#        'Nagpur', 'Indore', 'New York, Bengaluru', 'California', 'India',
#        'Ahemadabad', 'Rourkela', 'Srinagar', 'Bhubneswar', 'Chandigarh',
#        'Delhi & Cambridge', 'Kolkatta', 'Kolkata', 'Coimbatore',
#        'Bangalore', 'Udaipur', 'India_Other', 'Ahemdabad', 'Bhubaneswar',
#        'Ahmedabad', 'Surat', 'Goa', 'Uttar Pradesh', 'Nw Delhi', 'Gaya',
#        'Vadodara', 'Trivandrum', 'Missourie', 'Panaji', 'Gwalior',
# ...

# %%
sfin['City  Location'].value_counts()
# Out:
# Bangalore                 700
# Mumbai                    567
# New Delhi                 421
# Gurgaon                   287
# India_Other               180
# Bengaluru                 141
# Pune                      105
# Hyderabad                 99
# Chennai                   97
# Noida                     92
# Gurugram                  50
# Ahmedabad                 38
# Delhi                     34
# Jaipur                    30
# Kolkata                   21
# Indore                    13
# Chandigarh                11
# Vadodara                  10
# Goa                       10
# Singapore                 8
# Coimbatore                5
# Pune / US                 4
# Kanpur                    4
# \\xc2\\xa0Gurgaon         4
# Nagpur                    3
# Faridabad                 3
# \\xc2\\xa0New Delhi       3
# Bhopal                    3
# Kochi                     2
# Siliguri                  2
#                          ..
# Menlo Park                1
# ...

# %%
#Create Top 6 city list
Delhi_NCR=['New Delhi','Gurgaon','Noida','Gurugram','Faridabad','Delhi','Delhi & Cambridge','New Delhi / US','Gurgaon / SFO','New Delhi / California','Noida / Singapore',
    'New Delhi/ Houston','\\\\xc2\\\\xa0Noida','\\\\xc2\\\\xa0Gurgaon', '\\\\xc2\\\\xa0New Delhi','New Delhi / California','Nw Delhi']
Bengaluru_area=['Bengaluru','Bangalore','Bangalore/ Bangkok','SFO / Bangalore','Seattle / Bangalore','Bangalore / SFO','Bangalore / Palo Alto','Bangalore / San Mateo','Bangalore / USA','\\\\xc2\\\\xa0Bangalore','Kormangala','New York, Bengaluru']
Mumbai_area = ['Mumbai','Andheri', 'Chembur','Mumbai / UK','Mumbai / NY','Mumbai / Global','\\\\xc2\\\\xa0Mumbai']
Pune_area=['Pune','Pune/Seattle', 'Pune / Dubai','Pune / US','Pune / Singapore']
Hyderabad_area=['Hyderabad','Hyderabad/USA','Dallas / Hyderabad']
Chennai_area=['Chennai','Taramani','Chennai/ Singapore']

# %%
sfin['Sorted_Cities']=sfin['City  Location']
for x in sfin['Sorted_Cities']:
    if x in Delhi_NCR:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Delhi_NCR')
    elif x in Bengaluru_area:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Bengaluru_area')
    elif x in Mumbai_area:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Mumbai_area')
    elif x in Pune_area:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Pune_area')
    elif x in Hyderabad_area:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Hyderabad_area')
    elif x in Chennai_area:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Chennai_area')

# %%
sfin['Sorted_Cities'].unique()
# Out:
# array(['Bengaluru_area', 'Delhi_NCR', 'Mumbai_area', 'Chennai_area',
#        'Pune_area', 'San Francisco', 'San Jose,', 'Amritsar', 'Tulangan',
#        'Hyderabad_area', 'Burnsville', 'Menlo Park', 'Palo Alto',
#        'Santa Monica', 'Singapore', 'Nairobi', 'Haryana', 'New York',
#        'Karnataka', 'Mumbai/Bengaluru', 'Bhopal',
#        'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US',
#        'Nagpur', 'Indore', 'California', 'India', 'Ahemadabad',
#        'Rourkela', 'Srinagar', 'Bhubneswar', 'Chandigarh', 'Kolkatta',
#        'Kolkata', 'Coimbatore', 'Udaipur', 'India_Other', 'Ahemdabad',
#        'Bhubaneswar', 'Ahmedabad', 'Surat', 'Goa', 'Uttar Pradesh',
#        'Gaya', 'Vadodara', 'Trivandrum', 'Missourie', 'Panaji', 'Gwalior',
#        'Karur', 'Udupi', 'Kochi', 'Agra', 'Hubli', 'Kerala', 'Kozhikode',
#        'US', 'Siliguri', 'USA', 'Lucknow', 'Kanpur', 'London', 'Varanasi',
#        'Jodhpur', 'Boston', 'USA/India', 'Goa/Hyderabad', 'Belgaum',
# ...

# %%
sfin['Sorted_Cities'].value_counts()
# Out:
# Delhi_NCR           903
# Bengaluru_area      854
# Mumbai_area         573
# India_Other         180
# Pune_area           112
# Hyderabad_area      101
# Chennai_area        99
# Ahmedabad           38
# Jaipur              30
# Kolkata             21
# Indore              13
# Chandigarh          11
# Goa                 10
# Vadodara            10
# Singapore           8
# Coimbatore          5
# Kanpur              4
# Nagpur              3
# Bhopal              3
# San Francisco       2
# Udaipur             2
# Kochi               2
# Siliguri            2
# Udupi               2
# India/US            2
# Gwalior             2
# Surat               2
# Agra                2
# Mumbai/Bengaluru    2
# Ahemadabad          2
#                    ..
# Boston              1
# Varanasi            1
# US/India            1
# Jodhpur             1
# Uttar Pradesh       1
# Tulangan            1
# Santa Monica        1
# India/Singapore     1
# Rourkela            1
# ...

# %%
top_6_cities = ['Delhi_NCR','Bengaluru_area','Mumbai_area','Pune_area','Hyderabad_area','Chennai_area']

# %%
for x in sfin['Sorted_Cities']:
    if x in top_6_cities:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities']
    else:
        sfin['Sorted_Cities'] = sfin['Sorted_Cities'].replace(to_replace=x, value='Others')

# %%
sfin['Sorted_Cities'].value_counts()
# Out:
# Delhi_NCR         903
# Bengaluru_area    854
# Mumbai_area       573
# Others            402
# Pune_area         112
# Hyderabad_area    101
# Chennai_area      99
# Name: Sorted_Cities, dtype: int64

# %%
sfin.head()
# Out:
#                    Startup Name    Industry Vertical  \
# 0  BYJU’S                        E-Tech
# 1  Shuttl                        Transportation
# 2  Mamaearth                     E-commerce
# 3  https://www.wealthbucket.in/  FinTech
# 4  Fashor                        Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0  E-learning                             Bengaluru
# 1  App based shuttle service              Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3  Online Investment                      New Delhi
# 4  Embroiled Clothes For Women            Mumbai
#
#               Investors Name       InvestmentnType       date       amount  \
# 0  Tiger Global Management    private equity round 2020-09-01  200000000.0
# 1  Susquehanna Growth Equity  series c             2020-01-13  8048394.0
# 2  Sequoia Capital India      series b             2020-09-01  18358860.0
# ...

# %%
sfin['industry_vertical']=sfin['Industry Vertical'].str.lower()
sfin['SubVertical']=sfin['SubVertical'].str.lower()
sfin['sort_ind_vert']=sfin['SubVertical']

# %%
sfin.head()
# Out:
#                    Startup Name    Industry Vertical  \
# 0  BYJU’S                        E-Tech
# 1  Shuttl                        Transportation
# 2  Mamaearth                     E-commerce
# 3  https://www.wealthbucket.in/  FinTech
# 4  Fashor                        Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0  e-learning                             Bengaluru
# 1  app based shuttle service              Gurgaon
# 2  retailer of baby and toddler products  Bengaluru
# 3  online investment                      New Delhi
# 4  embroiled clothes for women            Mumbai
#
#               Investors Name       InvestmentnType       date       amount  \
# 0  Tiger Global Management    private equity round 2020-09-01  200000000.0
# 1  Susquehanna Growth Equity  series c             2020-01-13  8048394.0
# 2  Sequoia Capital India      series b             2020-09-01  18358860.0
# ...

# %%
sfin.drop(['Industry Vertical'],1,inplace=True)
"""# replacing generic classifications like Consumer Internet, Technology with Sub-verticle data
sfin.sort_ind_vert.replace('consumer internet',sfin.SubVertical,inplace=True)
sfin.sort_ind_vert.replace('technology',sfin.SubVertical,inplace=True)"""
# Out:
# "# replacing generic classifications like Consumer Internet, Technology with Sub-verticle data\nsfin.sort_ind_vert.replace('consumer internet',sfin.SubVertical,inplace=True)\nsfin.sort_ind_vert.replace('technology',sfin.SubVertical,inplace=True)"

# %%
sfin['sort_ind_vert'].value_counts()
# Out:
# unclassified                                               171
# online lending platform                                    21
# food delivery platform                                     14
# online pharmacy                                            11
# online education platform                                  10
# online learning platform                                   10
# online food delivery                                       9
# online payment gateway                                     6
# online marketplace                                         6
# data analytics platform                                    5
# online consumer lending platform                           5
# ecommerce marketplace                                      5
# education                                                  5
# health-tech platform                                       5
# online food delivery platform                              5
# ...

# %%
#start of cleaning process
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace='-', value='', regex=True)
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=' & ', value='_', regex=True)
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace='app', value='', regex=True)
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=' and ', value='_', regex=True)

# %%
# Finding the keywords
srt=sfin['sort_ind_vert']
from collections import Counter
p = Counter(" ".join(srt).split()).most_common(60)
result = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(result)
# Out:
#             Word  Frequency
# 0   platform      1020
# 1   online        607
# 2   mobile        254
# 3   marketplace   230
# 4   for           198
# 5   unclassified  171
# 6   services      152
# 7   solutions     138
# 8   based         126
# 9   service       98
# 10  food          94
# 11  portal        93
# 12  provider      91
# 13  lending       86
# 14  delivery      85
# 15  etailer       85
# 16  management    82
# 17  ecommerce     79
# 18  aggregator    73
# 19  fashion       69
# 20  rental        64
# 21  discovery     61
# 22  logistics     59
# 23  healthcare    58
# 24  hyperlocal    56
# 25  home          54
# 26  education     53
# 27  software      52
# 28  social        51
# 29  learning      51
# 30  products      49
# 31  digital       48
# 32  booking       45
# 33  analytics     44
# 34  data          43
# 35  ondemand      42
# 36  startup       41
# 37  health        38
# 38  b2b           36
# 39  solution      36
# 40  car           35
# ...

# %%
#checking against top services, markets
sfin['sort_ind_vert'].value_counts()
# Out:
# unclassified                                   171
# online lending platform                        21
# food delivery platform                         14
# online pharmacy                                11
# online learning platform                       10
# online education platform                      10
# online food delivery                           9
# online marketplace                             6
# online payment gateway                         6
# online food delivery platform                  5
# data analytics platform                        5
# ecommerce marketplace                          5
# online consumer lending platform               5
# nonbanking financial company                   5
# education                                      5
# agritech                                       5
# online lending                                 5
# healthtech platform                            5
# online insurance platform                      4
# ...

# %%
#long and painful process of sorting and cleaning data based on key words, target >80% w/o unclassified data accounted for
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('food')], value='food_beverages_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('health')], value='meditech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('transport')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('logistics')], value='logistics_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('education')], value='edtech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('edtech')], value='edtech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('learning')], value='edtech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('hyperlocal')], value='hyperlocal_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('fin')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('marketplace')], value='marketplace_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('software')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('cloud')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('restaurant')], value='food_beverages_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('ecommerce')], value='ecommerce_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('data')], value='AI_Data_analytics_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('intelligence')], value='AI_Data_analytics_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('analytics')], value='AI_Data_analytics_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('estate')], value='real_estate_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('real estate')], value='real_estate_services')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('lending')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('etailer')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('fashion')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('agri')], value='agritech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('medic')], value='meditech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('grocery')], value='ecommerce_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('payment')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('pharmacy')], value='meditech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('hotel')], value='travel_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('travel')], value='travel_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('insurance')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('doctor')], value='meditech_industry')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('assistant')], value='AI_Data_analytics_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('investment')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('bike')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('taxi')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('electric')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('pooling')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('care')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('card')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('car')], value='transport_industry')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('beauty')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('loan')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('wallet')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('funding')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('commerce')], value='ecommerce_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('truck')], value='logistics_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('vehicle')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('cab')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('automo')], value='transport_industry')#automotive, automobile
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('freight')], value='logistics_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('online')], value='online_and_booking_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('booking')], value='online_and_booking_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('entertainment')], value='media_entertainment_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('social')], value='media_entertainment_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('ondemand')], value='online_and_booking_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('mile')], value='logistics_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('marketing')], value='media_entertainment_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('news')], value='media_entertainment_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('media')], value='media_entertainment_services')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('fitness')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('saas')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('video')], value='media_entertainment_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('securinformation')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('scooter')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('gam')], value='media_entertainment_services')#gaming
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('employee')], value='b2b_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('b2b')], value='b2b_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('enterprise')], value='b2b_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('mobile')], value='online_and_booking_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('property')], value='real_estate_services')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('wealth')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('home')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('interior')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('parking')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('ticket')], value='ecommerce_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('delivery')], value='hyperlocal_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('discovery')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('cancer')], value='meditech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('energy')], value='energy_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('solar')], value='energy_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('cyber')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('diag')], value='meditech_industry')

# %%
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('shuttle')], value='transport_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('money')], value='fintech_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('clinic')], value='meditech_industry')

# %%
#testing 'key word' for sorting data
i = ['data','analytics']
sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('clinic',regex=True)]
# Out:
# Series([], Name: sort_ind_vert, dtype: object)

# %%
#Indentifying the top key words for sorting
srt=sfin['sort_ind_vert']
from collections import Counter
p = Counter(" ".join(srt).split()).most_common(60)
result = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(result)
# Out:
#                             Word  Frequency
# 0   online_and_booking_services   346
# 1   fintech_services              267
# 2   lifestyle_services            229
# 3   meditech_industry             206
# 4   marketplace_services          205
# 5   unclassified                  171
# 6   platform                      163
# 7   edtech_industry               135
# 8   food_beverages_industry       131
# 9   media_entertainment_services  121
# 10  transport_industry            119
# 11  AI_Data_analytics_services    108
# 12  software_cloud_services       106
# 13  ecommerce_industry            105
# 14  logistics_industry            86
# 15  hyperlocal_services           62
# 16  travel_industry               58
# 17  for                           35
# 18  solutions                     30
# 19  real_estate_services          25
# 20  management                    24
# 21  services                      24
# 22  provider                      22
# 23  b2b_services                  21
# ...

# %%
top_services = ['online_and_booking_services','fintech_services','lifestyle_services','marketplace_services','meditech_industry','unclassified','edtech_industry','online_services','edtech_industry','food_beverages_industry','media_entertainment_services','transport_industry','AI_Data_analytics_services','software_cloud_services',
                'ecommerce_industry','logistics_industry','hyperlocal_services','travel_industry','real_estate_services','b2b_services','agritech_industry','energy_industry']

# %%
print(top_services)
# Out:
# ['online_and_booking_services', 'fintech_services', 'lifestyle_services', 'marketplace_services', 'meditech_industry', 'unclassified', 'edtech_industry', 'online_services', 'edtech_industry', 'food_beverages_industry', 'media_entertainment_services', 'transport_industry', 'AI_Data_analytics_services', 'software_cloud_services', 'ecommerce_industry', 'logistics_industry', 'hyperlocal_services', 'travel_industry', 'real_estate_services', 'b2b_services', 'agritech_industry', 'energy_industry']

# %%
sfin.head(10)
# Out:
#                    Startup Name                               SubVertical  \
# 0  BYJU’S                        e-learning
# 1  Shuttl                        app based shuttle service
# 2  Mamaearth                     retailer of baby and toddler products
# 3  https://www.wealthbucket.in/  online investment
# 4  Fashor                        embroiled clothes for women
# 5  Pando                         open-market, freight management platform
# 6  Zomato                        online food delivery platform
# 7  Ecozen                        agritech
# 8  CarDekho                      automobile
# 9  Dhruva Space                  satellite communication
#
#   City  Location                  Investors Name       InvestmentnType  \
# 0  Bengaluru      Tiger Global Management         private equity round
# 1  Gurgaon        Susquehanna Growth Equity       series c
# 2  Bengaluru      Sequoia Capital India           series b
# ...

# %%
# Convert unstorable data to 'Unsorted services'
for x in sfin['sort_ind_vert']:
    if x in top_services:
        sfin['sort_ind_vert'] = sfin['sort_ind_vert']
    else:
        sfin['sort_ind_vert'] = sfin['sort_ind_vert'].replace(to_replace=x, value='unsorted_services')

# %%
sfin.head()
# Out:
#                    Startup Name                            SubVertical  \
# 0  BYJU’S                        e-learning
# 1  Shuttl                        app based shuttle service
# 2  Mamaearth                     retailer of baby and toddler products
# 3  https://www.wealthbucket.in/  online investment
# 4  Fashor                        embroiled clothes for women
#
#   City  Location             Investors Name       InvestmentnType       date  \
# 0  Bengaluru      Tiger Global Management    private equity round 2020-09-01
# 1  Gurgaon        Susquehanna Growth Equity  series c             2020-01-13
# 2  Bengaluru      Sequoia Capital India      series b             2020-09-01
# 3  New Delhi      Vinod Khatumal             pre-series a         2020-02-01
# 4  Mumbai         Sprout Venture Partners    seed round           2020-02-01
#
#         amount invst_type_sorted   Sorted_Cities    industry_vertical  \
# 0  200000000.0  private_angel     Bengaluru_area  e-tech
# ...

# %%
#still not meeting >80% target, to further improve unsorted use data from industry vertical instead of sub-vertical only for unsorted data
sfin.sort_ind_vert.replace('unsorted_services',sfin.industry_vertical,inplace=True)

# %%
sfin.head()
# Out:
#                    Startup Name                            SubVertical  \
# 0  BYJU’S                        e-learning
# 1  Shuttl                        app based shuttle service
# 2  Mamaearth                     retailer of baby and toddler products
# 3  https://www.wealthbucket.in/  online investment
# 4  Fashor                        embroiled clothes for women
#
#   City  Location             Investors Name       InvestmentnType       date  \
# 0  Bengaluru      Tiger Global Management    private equity round 2020-09-01
# 1  Gurgaon        Susquehanna Growth Equity  series c             2020-01-13
# 2  Bengaluru      Sequoia Capital India      series b             2020-09-01
# 3  New Delhi      Vinod Khatumal             pre-series a         2020-02-01
# 4  Mumbai         Sprout Venture Partners    seed round           2020-02-01
#
#         amount invst_type_sorted   Sorted_Cities    industry_vertical  \
# 0  200000000.0  private_angel     Bengaluru_area  e-tech
# ...

# %%
sfin['sort_ind_vert'].value_counts()
# Out:
# online_and_booking_services                     346
# fintech_services                                267
# lifestyle_services                              229
# meditech_industry                               206
# marketplace_services                            205
# unclassified                                    171
# edtech_industry                                 135
# consumer internet                               132
# food_beverages_industry                         131
# technology                                      129
# media_entertainment_services                    121
# transport_industry                              119
# AI_Data_analytics_services                      108
# software_cloud_services                         106
# ecommerce_industry                              105
# logistics_industry                              86
# hyperlocal_services                             62
# travel_industry                                 58
# ...

# %%
# final sorting checked and stopped at ~81% of data without 'unclassified' and 'unsorted'
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('commerce')], value='ecommerce_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('health')], value='meditech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('food')], value='food_beverages_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('fin')], value='fintech_services')#financial, finance, fin-tech..
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('logistics')], value='logistics_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('education')], value='edtech_industry')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('real estate')], value='real_estate_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('fashion')], value='lifestyle_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('software')], value='software_cloud_services')
sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('apparel')], value='lifestyle_services')

#sfin['sort_ind_vert']=sfin['sort_ind_vert'].replace(to_replace=sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('education')], value='edtech_industry')

# %%
# Finding the keywords
srt=sfin['sort_ind_vert']
from collections import Counter
p = Counter(" ".join(srt).split()).most_common(60)
result = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(result)
# Out:
#                             Word  Frequency
# 0   online_and_booking_services   346
# 1   fintech_services              278
# 2   lifestyle_services            234
# 3   meditech_industry             224
# 4   marketplace_services          205
# 5   unclassified                  171
# 6   food_beverages_industry       153
# 7   edtech_industry               140
# 8   internet                      135
# 9   consumer                      132
# 10  technology                    131
# 11  ecommerce_industry            123
# 12  media_entertainment_services  121
# 13  transport_industry            119
# 14  software_cloud_services       108
# 15  AI_Data_analytics_services    108
# 16  logistics_industry            92
# 17  hyperlocal_services           62
# 18  travel_industry               58
# 19  platform                      51
# 20  real_estate_services          30
# 21  b2b_services                  21
# 22  agritech_industry             17
# 23  energy_industry               16
# ...

# %%
sfin['sort_ind_vert'].value_counts()
# Out:
# online_and_booking_services                                 346
# fintech_services                                            278
# lifestyle_services                                          234
# meditech_industry                                           224
# marketplace_services                                        205
# unclassified                                                171
# food_beverages_industry                                     153
# edtech_industry                                             140
# consumer internet                                           132
# technology                                                  129
# ecommerce_industry                                          123
# media_entertainment_services                                121
# transport_industry                                          119
# software_cloud_services                                     108
# AI_Data_analytics_services                                  108
# ...

# %%
#testing 'key word' for sorting data
i = ['data','analytics']
sfin['sort_ind_vert'].loc[sfin['sort_ind_vert'].str.contains('apparel',regex=True)]
# Out:
# Series([], Name: sort_ind_vert, dtype: object)

# %%
sfin.head(100)
# Out:
#                     Startup Name                               SubVertical  \
# 0   BYJU’S                        e-learning
# 1   Shuttl                        app based shuttle service
# 2   Mamaearth                     retailer of baby and toddler products
# 3   https://www.wealthbucket.in/  online investment
# 4   Fashor                        embroiled clothes for women
# 5   Pando                         open-market, freight management platform
# 6   Zomato                        online food delivery platform
# 7   Ecozen                        agritech
# 8   CarDekho                      automobile
# 9   Dhruva Space                  satellite communication
# 10  Rivigo                        logistics services and solutions
# 11  Healthians                    food solutions for corporate
# 12  Licious                       online meat and seafood ordering startup
# 13  InCred                        non-banking financial company
# ...

# %%
# Final converttion unstorable data to 'Unsorted services'
for x in sfin['sort_ind_vert']:
    if x in top_services:
        sfin['sort_ind_vert'] = sfin['sort_ind_vert']
    else:
        sfin['sort_ind_vert'] = sfin['sort_ind_vert'].replace(to_replace=x, value='unsorted_services')

# %%
sfin.head()
# Out:
#                    Startup Name                            SubVertical  \
# 0  BYJU’S                        e-learning
# 1  Shuttl                        app based shuttle service
# 2  Mamaearth                     retailer of baby and toddler products
# 3  https://www.wealthbucket.in/  online investment
# 4  Fashor                        embroiled clothes for women
#
#   City  Location             Investors Name       InvestmentnType       date  \
# 0  Bengaluru      Tiger Global Management    private equity round 2020-09-01
# 1  Gurgaon        Susquehanna Growth Equity  series c             2020-01-13
# 2  Bengaluru      Sequoia Capital India      series b             2020-09-01
# 3  New Delhi      Vinod Khatumal             pre-series a         2020-02-01
# 4  Mumbai         Sprout Venture Partners    seed round           2020-02-01
#
#         amount invst_type_sorted   Sorted_Cities    industry_vertical  \
# 0  200000000.0  private_angel     Bengaluru_area  e-tech
# ...

# %%
sfin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 11 columns):
# Startup Name         3044 non-null object
# SubVertical          3044 non-null object
# City  Location       3044 non-null object
# Investors Name       3044 non-null object
# InvestmentnType      3040 non-null object
# date                 3044 non-null datetime64[ns]
# amount               2065 non-null float64
# invst_type_sorted    3044 non-null object
# Sorted_Cities        3044 non-null object
# industry_vertical    3044 non-null object
# sort_ind_vert        3044 non-null object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 261.7+ KB

# %%
sfin['sort_ind_vert'].value_counts()
# Out:
# unsorted_services               418
# online_and_booking_services     346
# fintech_services                278
# lifestyle_services              234
# meditech_industry               224
# marketplace_services            205
# unclassified                    171
# food_beverages_industry         153
# edtech_industry                 140
# ecommerce_industry              123
# media_entertainment_services    121
# transport_industry              119
# software_cloud_services         108
# AI_Data_analytics_services      108
# logistics_industry              92
# hyperlocal_services             62
# travel_industry                 58
# real_estate_services            30
# b2b_services                    21
# agritech_industry               17
# energy_industry                 16
# Name: sort_ind_vert, dtype: int64

# %%
sfin.describe()
# Out:
#              amount
# count  2.065000e+03
# mean   1.842990e+07
# std    1.213734e+08
# min    1.600000e+04
# 25%    4.700000e+05
# 50%    1.700000e+06
# 75%    8.000000e+06
# max    3.900000e+09

# %%
sfin.to_excel("Startup_information_cleaned.xlsx",sheet_name='cleaned_sorted')

# %%
#sfin.close()
